# %% [markdown]
# # NFL Score Predictions
# ### Predict scores of NFL games based on FiveThirtyEight's pregame statistics.
# _________________________________________________________________

# %% [markdown]
# Import libraries and read in data set:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import calendar
from sklearn.model_selection import train_test_split

pd.set_option('display.max_columns', None)

# Read in the data set
games = pd.read_csv('../data/nfl_games.csv')
# Remove rows with NaN values
games = games.dropna()
games.head(3)
# Out:
#          date  season  neutral  playoff team1 team2      elo1    elo2  \
# 0  1920-09-26    1920        0        0   RII   STP  1503.947  1300.0
# 1  1920-10-03    1920        0        0   AKR   WHE  1503.420  1300.0
# 2  1920-10-03    1920        0        0   RCH   ABU  1503.420  1300.0
#
#    elo_prob1  score1  score2  result1
# 0   0.824651      48       0      1.0
# 1   0.824212      43       0      1.0
# 2   0.824212      10       0      1.0

# %% [markdown]
# ## Exploratory Data Analysis
# ___
#
# ### 1. Explore Correlation Between Dates and Score

# %%
games["totalScore"] = games["score1"] + games["score2"]

# Put date column in YYYYMMDD format, create month and day column
games["date"] = pd.to_datetime(games["date"]).dt.strftime("%Y%m%d").astype(int)
games["month"] = [calendar.month_abbr[int((i%10000)/100)] for i in games["date"]]
games["day"] = [int(i%100) for i in games["date"]]
games.head(3)
# Out:
#        date  season  neutral  playoff team1 team2      elo1    elo2  \
# 0  19200926    1920        0        0   RII   STP  1503.947  1300.0
# 1  19201003    1920        0        0   AKR   WHE  1503.420  1300.0
# 2  19201003    1920        0        0   RCH   ABU  1503.420  1300.0
#
#    elo_prob1  score1  score2  result1  totalScore month  day
# 0   0.824651      48       0      1.0          48   Sep   26
# 1   0.824212      43       0      1.0          43   Oct    3
# 2   0.824212      10       0      1.0          10   Oct    3

# %%
# Plot Season, Month, and Day vs. Total Score
f, axs = plt.subplots(3,1,figsize=(10,10))
plt.subplot(311)
plt.xlabel("Season")
plt.ylabel("Total Score")
plt.scatter(games.season, games.totalScore)
plt.subplot(312)
plt.xlabel("Day")
plt.ylabel("Total Score")
plt.scatter(games.day, games.totalScore)
plt.subplot(313)
plt.xlabel("Month")
plt.ylabel("Total Score")
plt.scatter(games.month, games.totalScore)
plt.show()

# Print the number of games played in each month
for i in np.unique(games["month"].values):
    print("Number of games in %s: %d" % (i, (games.month == i).sum()))
# Out:
# Number of games in Aug: 22
# Number of games in Dec: 3591
# Number of games in Feb: 17
# Number of games in Jan: 552
# Number of games in Nov: 4521
# Number of games in Oct: 4462
# Number of games in Sep: 3109

# %% [markdown]
# **Conclusions:**
# - Total score for games seems to increase as the season increases, so season may be a valuable attribute.
# - Day has no correlation on score, and is therefore not useful.
# - August and Feburary appeared to have different scores than the other months, but their sample sizes (22 and 17, respectively) are too small to indicate any pattern. Also, the other months did not follow any pattern, so month is not useful.
#
# ### 2. Neutral and Playoff Game Frequency

# %%
# Calculate percentage of games that are neutral/playoff games
neutralGames = (games.neutral == 1).sum()
playoffGames = (games.playoff == 1).sum()
totalGames = games.shape[0]
print("Neutral Game Percentage = %d/%d = %6.6f%%" %
      (neutralGames, totalGames, neutralGames/totalGames * 100))
print("Playoff Game Percentage = %d/%d = %6.6f%%" %
      (playoffGames, totalGames, playoffGames/totalGames * 100))

# TODO: show avg totalScore for playoff games and non playoff games, if
# similar them remove playoff as well
# Out:
# Neutral Game Percentage = 85/16274 = 0.522306%
# Playoff Game Percentage = 566/16274 = 3.477940%

# %% [markdown]
# **Conclusions:**
# - There are too few neutral site games for them to be useful.
# - There is also not very many playoff games, but there is enough for me to believe it could be useful in my model.
#
# ### 3. Team Points Per Game (PPG)

# %%
# Calculate the historical points per game for each team 
ppg = []
for i in np.unique(games[['team1', 'team2']].values):
    # find all instances of score1 when i == team1
    i1 = games.loc[games['team1'] == i].score1
    # find all instances of score2 when i == team2
    i2 = games.loc[games['team2'] == i].score2
    ppg.append(
        (i1.sum() + i2.sum()) / (i1.shape[0] + i2.shape[0])
    )

# Create a DataFrame for a team's ppg
ppgDf = pd.DataFrame({'team': np.unique(games[['team1', 'team2']].values), 'ppg': ppg})
ppgDfSample = ppgDf.sample(20)

# Plot team name vs. ppg
f, axs = plt.subplots(2,1,figsize=(10,8))
plt.subplot(211)
plt.title("A Sample of Teams")
plt.ylabel("PPG")
plt.scatter(ppgDfSample.team, ppgDfSample.ppg)
plt.subplot(212)
plt.title("All of the Teams")
plt.ylabel("PPG")
plt.scatter(ppgDf.team, ppgDf.ppg)
plt.show()

# %% [markdown]
# **Conclusion:** points scored per game depends on the team, which means that combining team and PPG as attributes in our data set should improve our model.
#
# ## Feature Engineering
# ___
#
# Improve data set based on the exploratory data analysis.
#
# ### 1. Remove Extra Information
# - Remove totalScore column since I only used it for plotting.
# - Remove result1 column because we cannot use post-game stats for pregame score predictions.

# %%
del games["totalScore"]
del games["result1"]

# %% [markdown]
# ### 2. Date information
# - Remove day column since it was determined it is not useful.
# - Remove month column since it was determined it is not useful.
# - Remove date column since the year, which is the only useful part of the date, is tracked in the season column.

# %%
del games["day"]
del games["month"]
del games["date"]

# %% [markdown]
# ### 3. Game Type
# - Remove the neutral column to avoid the few neutral games skewing our models.
# - Keep the playoff column because there are a fair amount of playoff games.

# %%
del games["neutral"]

# %% [markdown]
# ### 4. Add PPG
# Add points per game for each team to the DataFrame since it should help predict a team's score.

# %%
# Add ppg for team1

# Merge the ppgDf (team, ppg) into the games DataFrame
games = games.merge(ppgDf, how='inner', left_on='team1', right_on='team')
# Delete the redundant team column
del games["team"]
# Rename ppg column to ppg1, to signify it's team1's ppg
games.rename(columns={"ppg": "ppg1"}, inplace=True)

# Add ppg for team2

# Merge the ppgDf (team, ppg) into the games DataFrame
games = games.merge(ppgDf, how='inner', left_on='team2', right_on='team')
# Delete the redundant team column
del games["team"]
# Rename ppg column to ppg2, to signify it's team2's ppg
games.rename(columns={"ppg": "ppg2"}, inplace=True)

games.sample(3)
# Out:
#       season  playoff team1 team2         elo1        elo2  elo_prob1  score1  \
# 355     1999        0   WSH   CHI  1541.347000  1410.24000   0.755633      48
# 7723    2018        1   HOU   IND  1551.182065  1577.74081   0.555097       7
# 4247    1958        0   NYG   WSH  1537.185000  1459.36300   0.694692      30
#
#       score2       ppg1       ppg2
# 355       22  19.912698  19.295359
# 7723      21  20.610714  21.640428
# 4247       0  19.202920  19.912698

# %% [markdown]
# ### 5. One-Hot Encode the Teams
# Team name is valuable since different teams had varying PPG. Since the team attribute is discrete, we will one-hot encode it.

# %%
# One-hot encode the two teams
games = pd.get_dummies(
    games,
    columns=['team1', 'team2'],
    sparse=True
)

games.sample(3)
# Out:
#        season  playoff      elo1      elo2  elo_prob1  score1  score2  \
# 6294     1954        0  1549.416  1632.297   0.474290      17       7
# 6212     1957        0  1492.955  1459.738   0.637697      42       7
# 11624    1967        0  1514.838  1464.077   0.660691       0      23
#
#             ppg1       ppg2  team1_AKR  team1_ARI  team1_ATL  team1_BAL  \
# 6294   19.932746  20.246166          0          0          0          0
# 6212   19.912698  20.246166          0          0          0          0
# 11624  20.021505  22.705329          0          0          0          0
#
#        team1_BBA  team1_BCL  team1_BDA  team1_BFF  team1_BKN  team1_BRL  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team1_BUF  team1_BYK  team1_CAR  team1_CBD  team1_CHB  team1_CHI  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          1          0          0          0          0          0
#
#        team1_CHL  team1_CHT  team1_CIB  team1_CIN  team1_CLE  team1_CLI  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team1_COL  team1_CRA  team1_CRP  team1_CST  team1_CTI  team1_DAL  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team1_DAY  team1_DEN  team1_DET  team1_DHR  team1_DPN  team1_DTI  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team1_DTX  team1_DUL  team1_DWL  team1_ECG  team1_ELY  team1_FTW  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team1_FYJ  team1_GAR  team1_GB  team1_GUN  team1_HAM  team1_HOU  \
# 6294           0          0         0          0          0          0
# 6212           0          0         0          0          0          0
# 11624          0          0         0          0          0          0
#
#        team1_HRT  team1_IND  team1_JAX  team1_KC  team1_KCB  team1_KEN  \
# 6294           0          0          0         0          0          0
# 6212           0          0          0         0          0          0
# 11624          0          0          0         0          0          0
#
#        team1_LAC  team1_LAR  team1_LDA  team1_LOG  team1_LOU  team1_MIA  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team1_MIL  team1_MIN  team1_MNM  team1_MNN  team1_MSA  team1_MUN  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team1_NAA  team1_NE  team1_NG1  team1_NO  team1_NYA  team1_NYG  \
# 6294           0         0          0         0          0          0
# 6212           0         0          0         0          0          0
# 11624          0         0          0         0          0          0
#
#        team1_NYJ  team1_NYY  team1_OAK  team1_OOR  team1_PHI  team1_PIT  \
# 6294           0          0          0          0          0          1
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team1_PRV  team1_PTB  team1_PUL  team1_RAC  team1_RCH  team1_RCK  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team1_RED  team1_RIC  team1_RII  team1_ROS  team1_SEA  team1_SEN  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team1_SF  team1_SIS  team1_SLA  team1_STG  team1_TB  team1_TEN  \
# 6294          0          0          0          0         0          0
# 6212          0          0          0          0         0          0
# 11624         0          0          0          0         0          0
#
#        team1_THO  team1_TOL  team1_TOR  team1_UAP  team1_WGC  team1_WSH  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          1
# 11624          0          0          0          0          0          0
#
#        team1_ZAN  team2_ABU  team2_AKR  team2_ARI  team2_ATL  team2_ATN  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team2_BAL  team2_BBA  team2_BCL  team2_BDA  team2_BFF  team2_BKN  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team2_BRL  team2_BUF  team2_BYK  team2_CAR  team2_CBD  team2_CCL  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team2_CHI  team2_CHT  team2_CIB  team2_CIN  team2_CLE  team2_CLI  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team2_CLP  team2_CNC  team2_COL  team2_CRA  team2_CRP  team2_CTI  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team2_CWP  team2_DAL  team2_DAY  team2_DEN  team2_DET  team2_DHR  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team2_DPN  team2_DTI  team2_DTM  team2_DTX  team2_DUL  team2_DWL  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team2_ECG  team2_FTP  team2_FYJ  team2_GB  team2_GUN  team2_HAM  \
# 6294           0          0          0         0          0          0
# 6212           0          0          0         0          0          0
# 11624          0          0          0         0          0          0
#
#        team2_HOU  team2_HRT  team2_IND  team2_JAX  team2_KC  team2_KCB  \
# 6294           0          0          0          0         0          0
# 6212           0          0          0          0         0          0
# 11624          0          0          0          0         0          0
#
#        team2_KEN  team2_KEW  team2_LAB  team2_LAC  team2_LAN  team2_LAR  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team2_LDA  team2_LOU  team2_MCK  team2_MIA  team2_MIL  team2_MIN  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team2_MNN  team2_MSA  team2_MUN  team2_MUT  team2_NAA  team2_NE  \
# 6294           0          0          0          0          0         0
# 6212           0          0          0          0          0         0
# 11624          0          0          0          0          0         1
#
#        team2_NG1  team2_NO  team2_NYA  team2_NYG  team2_NYJ  team2_NYY  \
# 6294           0         0          0          0          0          0
# 6212           0         0          0          0          0          0
# 11624          0         0          0          0          0          0
#
#        team2_OAK  team2_OOR  team2_PHI  team2_PIT  team2_PRV  team2_PTB  \
# 6294           0          0          1          0          0          0
# 6212           0          0          1          0          0          0
# 11624          0          0          0          0          0          0
#
#        team2_PTQ  team2_RAC  team2_RCH  team2_RED  team2_RII  team2_ROS  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team2_SEA  team2_SF  team2_SIS  team2_SLA  team2_STG  team2_STP  \
# 6294           0         0          0          0          0          0
# 6212           0         0          0          0          0          0
# 11624          0         0          0          0          0          0
#
#        team2_SYR  team2_TB  team2_TEN  team2_THO  team2_TLM  team2_TOL  \
# 6294           0         0          0          0          0          0
# 6212           0         0          0          0          0          0
# 11624          0         0          0          0          0          0
#
#        team2_TON  team2_TOR  team2_UTI  team2_WBU  team2_WHE  team2_WJA  \
# 6294           0          0          0          0          0          0
# 6212           0          0          0          0          0          0
# 11624          0          0          0          0          0          0
#
#        team2_WSH
# 6294           0
# 6212           0
# 11624          0

# %% [markdown]
# ## Regression Models
# _________________________
